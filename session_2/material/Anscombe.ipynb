# %% [markdown]
# # Francis Anscombe's Quartett - Why visualization is important
#
# https://en.wikipedia.org/wiki/Anscombe%27s_quartet
#
# * pip install seaborn

# %% [markdown]
# https://seaborn.pydata.org/

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
set1=df[df["dataset"]=="I"]
set2=df[df["dataset"]=="II"]
set3=df[df["dataset"]=="III"]
set4=df[df["dataset"]=="IV"]
set2
# Out:
#    dataset     x     y
# 11      II  10.0  9.14
# 12      II   8.0  8.14
# 13      II  13.0  8.74
# 14      II   9.0  8.77
# 15      II  11.0  9.26
# 16      II  14.0  8.10
# 17      II   6.0  6.13
# 18      II   4.0  3.10
# 19      II  12.0  9.13
# 20      II   7.0  7.26
# 21      II   5.0  4.74

# %%
print("Mean set1: {}".format(set1["x"].std()))
print("Mean set2: {}".format(set2["x"].std()))
print("Mean set3: {}".format(set3["x"].std()))
print("Mean set4: {}".format(set4["x"].std()))
# Out:
# Mean set1: 3.3166247903554
# Mean set2: 3.3166247903554
# Mean set3: 3.3166247903554
# Mean set4: 3.3166247903554

# %%
print("Variance set1: {}".format(set1["y"].var()))
print("Variance set2: {}".format(set2["y"].var()))
print("Variance set3: {}".format(set3["y"].var()))
print("Variance set4: {}".format(set4["y"].var()))
# Out:
# Variance set1: 4.127269090909091
# Variance set2: 4.127629090909091
# Variance set3: 4.12262
# Variance set4: 4.123249090909091

# %%
print("Correlation set1: {}".format(set1[["x","y"]].corr()))
print("Correlation set2: {}".format(set2[["x","y"]].corr()))
print("Correlation set3: {}".format(set3[["x","y"]].corr()))
print("Correlation set4: {}".format(set4[["x","y"]].corr()))
# Out:
# Correlation set1:           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000
# Correlation set2:           x         y
# x  1.000000  0.816237
# y  0.816237  1.000000
# Correlation set3:           x         y
# x  1.000000  0.816287
# y  0.816287  1.000000
# Correlation set4:           x         y
# x  1.000000  0.816521
# y  0.816521  1.000000

# %%
print("Covariance set1: {}".format(set1[["x","y"]].cov()))
print("Covariance set2: {}".format(set2[["x","y"]].cov()))
print("Covariance set3: {}".format(set3[["x","y"]].cov()))
print("Covariance set4: {}".format(set4[["x","y"]].cov()))
# Out:
# Covariance set1:         x         y
# x  11.000  5.501000
# y   5.501  4.127269
# Covariance set2:       x         y
# x  11.0  5.500000
# y   5.5  4.127629
# Covariance set3:         x        y
# x  11.000  5.49700
# y   5.497  4.12262
# Covariance set4:         x         y
# x  11.000  5.499000
# y   5.499  4.123249

# %%
# Show the results of a linear regression within each dataset
sns.set(style="ticks")
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})
