# %% [markdown]
# # Visualization examples

# %%
# !pip install seaborn matplotlib pandas numpy
# Out:
# Requirement already satisfied: seaborn in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (3.8.3)
# Requirement already satisfied: pandas in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
# Dataset: https://archive.ics.uci.edu/ml/datasets/wine+quality
white_wine = pd.read_csv('winequality-white_new.csv', sep=';')

# %%
# Show the data
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %% [markdown]
# # Visualization with Pandas

# %% [markdown]
# ## Simple Scatterplot of two variables

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html
white_wine.plot(kind='scatter',x='citric acid',y='chlorides',color='green')
# Out:
# <Axes: xlabel='citric acid', ylabel='chlorides'>

# %% [markdown]
# ## Histogram of one column

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html
white_wine["fixed acidity"].hist(bins=60, color='blue', edgecolor='black',  xlabelsize=12, ylabelsize=12, grid=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram of all columns

# %%
white_wine.hist(bins=15, color='blue', edgecolor='black',  xlabelsize=12, ylabelsize=12, grid=True)    
plt.tight_layout(rect=(0, 0, 3, 3))

# %% [markdown]
# # Visualization with Seaborn

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(white_wine['sulphates'], white_wine['alcohol'],alpha=0.4, edgecolors='w')
plt.xlabel('Sulphates')
plt.ylabel('Alcohol')
plt.title('Wine Sulphates - Alcohol Content',y=1.05)
# Out:
# Text(0.5, 1.05, 'Wine Sulphates - Alcohol Content')

# %% [markdown]
# ## Continuous histogram

# %%
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html
fig = plt.figure(figsize = (6, 4))
title = fig.suptitle("Alcohol", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,1, 1)
ax1.set_xlabel("Alcohol")
ax1.set_ylabel("Alcohol by Volume") 
sns.kdeplot(white_wine['alcohol'], ax=ax1, fill=True, color='blue')
# Out:
# <Axes: xlabel='Alcohol', ylabel='Alcohol by Volume'>

# %% [markdown]
# ## Box plot

# %%
f, ax  = plt.subplots(1, 1, figsize=(5,5))
f.suptitle('Wine Quality - Alcohol Content', fontsize=12)
sns.boxplot(x="quality", y="alcohol", data=white_wine)
ax.set_xlabel("Wine Quality",size = 12)
ax.set_ylabel("Wine Alcohol %",size = 12)
# Out:
# Text(0, 0.5, 'Wine Alcohol %')

# %% [markdown]
# ## Line plot

# %%
f, ax  = plt.subplots(1, 1, figsize=(10,10))
f.suptitle('Wine Quality - Alcohol Content', fontsize=12)
sns.lineplot(x="quality", y="alcohol", data=white_wine)
ax.set_xlabel("Wine Quality",size = 12)
ax.set_ylabel("Wine Alcohol %",size = 12)
# Out:
# Text(0, 0.5, 'Wine Alcohol %')

# %% [markdown]
# ## Pair plot

# %%
columns = ['alcohol', 'fixed acidity']
pp = sns.pairplot(white_wine[columns], height=2, aspect=2, plot_kws=dict(edgecolor="k", linewidth=0.5))

# %% [markdown]
# ## Heatmap of correlations

# %%
corr = white_wine.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.089021   0.023086            -0.049396
# volatile acidity            0.064286   0.070512            -0.097012
# citric acid                 0.094212   0.114364             0.094077
# residual sugar              1.000000   0.088685             0.299098
# chlorides                   0.088685   1.000000             0.101392
# free sulfur dioxide         0.299098   0.101392             1.000000
# total sulfur dioxide        0.401439   0.198910             0.615501
# density                     0.838966   0.257211             0.294210
# pH                         -0.194133  -0.090439            -0.000618
# sulphates                  -0.026664   0.016763             0.059217
# alcohol                    -0.450631  -0.360189            -0.250104
# quality                    -0.097577  -0.209934             0.008158
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.091070  0.265331 -0.425858  -0.017143
# volatile acidity                  0.089261  0.027114 -0.031915  -0.035728
# citric acid                       0.121131  0.149503 -0.163748   0.062331
# residual sugar                    0.401439  0.838966 -0.194133  -0.026664
# chlorides                         0.198910  0.257211 -0.090439   0.016763
# free sulfur dioxide               0.615501  0.294210 -0.000618   0.059217
# total sulfur dioxide              1.000000  0.529881  0.002321   0.134562
# density                           0.529881  1.000000 -0.093591   0.074493
# pH                                0.002321 -0.093591  1.000000   0.155951
# sulphates                         0.134562  0.074493  0.155951   1.000000
# alcohol                          -0.448892 -0.780138  0.121432  -0.017433
# quality                          -0.174737 -0.307123  0.099427   0.053678
#
#                        alcohol   quality
# fixed acidity        -0.120881 -0.113663
# volatile acidity      0.067718 -0.194723
# citric acid          -0.075729 -0.009209
# residual sugar       -0.450631 -0.097577
# chlorides            -0.360189 -0.209934
# free sulfur dioxide  -0.250104  0.008158
# total sulfur dioxide -0.448892 -0.174737
# density              -0.780138 -0.307123
# pH                    0.121432  0.099427
# sulphates            -0.017433  0.053678
# alcohol               1.000000  0.435575
# quality               0.435575  1.000000

# %%
hm = sns.heatmap(round(corr,2), annot=True, linewidths=.05)

# %% [markdown]
# # Wordcloud
#
# Documentation: https://github.com/amueller/word_cloud
#
# * pip install wordcloud

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp310-cp310-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from wordcloud) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mail\anaconda3\envs\webmining2024\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp310-cp310-win_amd64.whl (299 kB)
#    ---------------------------------------- 0.0/300.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.0 kB ? eta -:--:--
#    -------------------------------------- - 286.7/300.0 kB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 300.0/300.0 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import re
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline

# %%
url="https://www.spiegel.de/international/germany/what-next-attention-slowly-turns-to-the-mother-of-all-coronavirus-questions-a-853a559e-d454-41e2-b8f2-e8f2c8d5ca18"

# %%
# Request the website
req = requests.get(url)

# %%
# Create a Soup Object
website = BeautifulSoup(req.text, 'html')

# %%
regex = re.compile('(?=.*RichText.*)(?=.*word-wrap.*)')
textelements = website.findAll('div',{'class':regex})
wordstring=""
for text in textelements:
    x=text.findAll("p")
    for p in x:
        wordstring=wordstring+p.text

# %%
wordstring

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white', max_words=30).generate(wordstring)

# %%
plt.clf()
f = plt.subplots(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white', max_words=30).generate(wordstring)

# %%
plt.clf()
f = plt.subplots(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
